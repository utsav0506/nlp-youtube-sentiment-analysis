# %%
#Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %%
data = pd.read_csv('/content/Untitled spreadsheet - Sheet2.csv')
data.columns
data1=data.drop(['Name','Likes','Time','Reply Count'],axis=1)
data1
# Out:
#                                                Comment
# 0    The future belongs to those who believe in the...
# 1    Thanks for keeping us informed. I feel for our...
# 2    This video definitely sponsored by webull henc...
# 3    This is a great video I really appreciate the ...
# 4    I will forever appreciate this channel, you&#3...
# ..                                                 ...
# 727  Is there  a specific broker that you’d recommend?
# 728                              Amazing person ❤️❤️❤️
# 729            Buying Ea Sports, PayPal and Adobe 🚀🤑🌖💵
# 730                                                Hlo
# 731                                    First comment 🫠
#
# [732 rows x 1 columns]

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.8.0)

# %%
import pandas as pd
import emoji

file_path = '/content/Untitled spreadsheet - Sheet2.csv'
df = pd.read_csv(file_path)

def convert_emojis_to_words(text):
    return emoji.demojize(text)

column_name = "Comment"
df[column_name] = df[column_name].apply(convert_emojis_to_words)

output_file_path = "updated_dataset2.xlsx"
df.to_excel(output_file_path, index=False)

# %%
# !pip install -q xlrd
import pandas as pd
df = pd.read_excel('/content/updated_dataset2.xlsx')
df
# Out:
#                Name                                            Comment  \
# 0     Chris Madison  The future belongs to those who believe in the...
# 1      Owen Michael  Thanks for keeping us informed. I feel for our...
# 2     kyla matthews  This video definitely sponsored by webull henc...
# 3    Michael Henkel  This is a great video I really appreciate the ...
# 4        Ahmad Aziz  I will forever appreciate this channel, you&#3...
# ..              ...                                                ...
# 727           Irmak  Is there  a specific broker that you’d recommend?
# 728    Sayyed Bilal   Amazing person :red_heart::red_heart::red_heart:
# 729           Hehee  Buying Ea Sports, PayPal and Adobe :rocket::mo...
# 730             fab                                                Hlo
# 731           Naman                       First comment :melting_face:
#
#                      Time  Likes  Reply Count
# 0    2023-10-29T05:09:52Z     45           70
# 1    2023-10-28T20:44:18Z     25           26
# 2    2023-10-28T16:15:38Z      0            0
# 3    2023-10-28T14:18:20Z     33            9
# 4    2023-10-28T11:32:00Z     50           18
# ..                    ...    ...          ...
# 727  2023-02-06T15:00:52Z      0            2
# 728  2023-02-06T14:59:23Z      2            0
# 729  2023-02-06T14:54:33Z      0            1
# 730  2023-02-06T14:54:11Z      1            0
# 731  2023-02-06T14:54:02Z      1            0
#
# [732 rows x 5 columns]

# %%
data1=df.drop(['Name','Likes','Time','Reply Count'],axis=1)
data1
# Out:
#                                                Comment
# 0    The future belongs to those who believe in the...
# 1    Thanks for keeping us informed. I feel for our...
# 2    This video definitely sponsored by webull henc...
# 3    This is a great video I really appreciate the ...
# 4    I will forever appreciate this channel, you&#3...
# ..                                                 ...
# 727  Is there  a specific broker that you’d recommend?
# 728   Amazing person :red_heart::red_heart::red_heart:
# 729  Buying Ea Sports, PayPal and Adobe :rocket::mo...
# 730                                                Hlo
# 731                       First comment :melting_face:
#
# [732 rows x 1 columns]

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
data1["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data1["Comment"]]
data1["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data1["Comment"]]
data1["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data1["Comment"]]
data1['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data1["Comment"]]
score = data1["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data1["Sentiment"] = sentiment
data1.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                              Comment  Positive  Negative  \
# 0  The future belongs to those who believe in the...     0.271     0.029
# 1  Thanks for keeping us informed. I feel for our...     0.097     0.138
# 2  This video definitely sponsored by webull henc...     0.291     0.000
# 3  This is a great video I really appreciate the ...     0.292     0.044
# 4  I will forever appreciate this channel, you&#3...     0.318     0.000
#
#    Neutral  Compound Sentiment
# 0    0.700    0.9561  Positive
# 1    0.765   -0.3595  Negative
# 2    0.709    0.6956  Positive
# 3    0.664    0.9403  Positive
# 4    0.682    0.9678  Positive

# %%
data2=data1.drop(['Positive','Negative','Neutral','Compound'],axis=1)
data2.head()
# Out:
#                                              Comment Sentiment
# 0  The future belongs to those who believe in the...  Positive
# 1  Thanks for keeping us informed. I feel for our...  Negative
# 2  This video definitely sponsored by webull henc...  Positive
# 3  This is a great video I really appreciate the ...  Positive
# 4  I will forever appreciate this channel, you&#3...  Positive

# %%
import nltk
nltk.download('stopwords')
stop_words = stopwords.words('english')
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
snowball_stemer = SnowballStemmer(language="english")
lzr = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def text_processing(text):
    # convert text into lowercase
    text = text.lower()

    # remove new line characters in text
    text = re.sub(r'\n',' ', text)

    # remove punctuations from text
    text = re.sub('[%s]' % re.escape(punctuation), "", text)

    # remove references and hashtags from text
    text = re.sub("^a-zA-Z0-9$,.", "", text)

    # remove multiple spaces from text
    text = re.sub(r'\s+', ' ', text, flags=re.I)

    # remove special characters from text
    text = re.sub(r'\W', ' ', text)

    text = ' '.join([word for word in word_tokenize(text) if word not in stop_words])

    # stemming using porter stemmer from nltk package - msh a7sn 7aga - momken: lancaster, snowball
    # text=' '.join([porter_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([lancaster_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([snowball_stemer.stem(word) for word in word_tokenize(text)])

    # lemmatizer using WordNetLemmatizer from nltk package
    text=' '.join([lzr.lemmatize(word) for word in word_tokenize(text)])

    return text

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
data_copy = data2.copy()
data_copy.Comment = data_copy.Comment.apply(lambda text: text_processing(text))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
le = LabelEncoder()
data_copy['Sentiment'] = le.fit_transform(data_copy['Sentiment'])

# %%
processed_data = {
    'Sentence':data_copy.Comment,
    'Sentiment':data_copy['Sentiment']
}

processed_data = pd.DataFrame(processed_data)
processed_data.head()
# Out:
#                                             Sentence  Sentiment
# 0  future belongs believe beauty dream success st...          2
# 1  thanks keeping u informed feel country low inc...          0
# 2  video definitely sponsored webull hence ad see...          2
# 3  great video really appreciate dedication video...          2
# 4  forever appreciate channel you39ve helped fami...          2

# %%
processed_data['Sentiment'].value_counts()
# Out:
# 2    456
# 1    164
# 0    112
# Name: Sentiment, dtype: int64

# %%
if 2 > 1:
    print("This video is legitimate.")
else:
    print("This video is a fraud.")
# Out:
# This video is legitimate.

# %%
df_neutral = processed_data[(processed_data['Sentiment']==1)]
df_negative = processed_data[(processed_data['Sentiment']==0)]
df_positive = processed_data[(processed_data['Sentiment']==2)]

# upsample minority classes
df_negative_upsampled = resample(df_negative,
                                 replace=True,
                                 n_samples= 456,
                                 random_state=42)

df_neutral_upsampled = resample(df_neutral,
                                 replace=True,
                                 n_samples= 456,
                                 random_state=42)


# Concatenate the upsampled dataframes with the neutral dataframe
final_data = pd.concat([df_negative_upsampled,df_neutral_upsampled,df_positive])

# %%
final_data['Sentiment'].value_counts()
# Out:
# 0    456
# 1    456
# 2    456
# Name: Sentiment, dtype: int64

# %%
corpus = []
for sentence in final_data['Sentence']:
    corpus.append(sentence)
corpus[0:5]
# Out:
# ['dosent teach u shit telling u already know wan na trade aint retarded',
#  'incurred much loss trading owni trade well demo think real market manipulated anyone help least tell i39m wrong',
#  'complete bullshit video',
#  'man wbri wan na become trader i39m still learning cuz know nothing facewithtearsofjoybut feel like app showed u make learn morebrthanks alot',
#  'webull weeee bullllll webull webull webull aight got one earned another sub funny hell']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()
y = final_data.iloc[:, -1].values

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=1500)
X = cv.fit_transform(corpus).toarray()
y = final_data.iloc[:, -1].values

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[131,   1,   6],
#        [  4, 120,   8],
#        [ 22,  19, 100]])

# %%
nb_score = accuracy_score(y_test, y_pred)
print('accuracy',nb_score)
# Out:
# accuracy 0.8540145985401459
